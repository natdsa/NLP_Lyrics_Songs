# %% [markdown]
# <h1><center>  Natural Language Processing - Análise de Letras de Música </center></h1>
#
# **Autora**: Natália da Silva Antunes <br>
# **Contato**: nantunest@gmail.com <br>
# **Portfólio**: [GitHub](github.com/natdsa)
# _________________________________________________________
#
#
# O objetivo deste estudo é empregar técnicas de Processamento de Linguagem Natural em letras de música de alguns artistas brasileiros. Foram coletadas todas as letras de músicas de cada artista, disponíveis no [Genius](https://genius.com).
#
# Nesse trabalho foram consideradas 360 letras de músicas dos seguintes artistas: Criolo, Fernandinho, Os Barões da Pisadinha e Pitty. A escolha dos artistas foi motivada por possuírem gêneros musicais distintos, possibilitando trazer uma maior diversidade ao conjunto de dados.
#
# O trabalho foi desenvolvido utilizando a linguagem Python/ Jupyter Notebook. Todas as bibliotecas utilizadas encontram-se disponíveis neste. Para a representação textual foram utilizadas as seguintes técnicas de NLP: Embedding, similaridade de palavras, bigramas, Análise de Sentimentos (Textblob e Afinn).
#
# Em resumo, o pipeline de dados foi realizado da seguinte maneira:
# 1.	Coleta de dados, mediante uso de API
# 2.	Agrupamento e tratamento dos dados
# 3.	Preprocessamento do texto
# 4.	Aplicação de técnicas de representação textual
# 5.	Aplicação de técnicas de análise de sentimentos
# 6.	Tópico por artista: Representação de palavras mais faladas e bigrama.

# %% [markdown]
# ## 1. Criando o dataset
#
# Para realizar a análise do conteúdo textual das músicas, será necessário a recuperação dessa informação. As letras de música serão extraidas do site [Genius](https://genius.com/), mediante uso da biblioteca lyricsgenius [Genius API Documentation](https://lyricsgenius.readthedocs.io/en/master/).
# Caso não possua token, será necessário o registro na plataforma. [Acesse aqui](https://genius.com/api-clients/new).
#
# Para este estudo, foram escolhidos previamente 4 artistas brasileiros, de gêneros musicais distintos.

# %%
import pandas as pd
import os
import json
import re
from lyricsgenius import Genius
from os import listdir
from os.path import isfile, join
import numpy as np
import nltk
from nltk.util import ngrams
from nltk.corpus import stopwords
import string
from unidecode import unidecode
from nltk.tokenize import sent_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from gensim.models import word2vec
from textblob import TextBlob
from afinn import Afinn
from gensim.models import word2vec
import gensim
from tqdm._tqdm_notebook import tqdm_notebook
from nltk import bigrams
from afinn import Afinn
# Out:
# <ipython-input-1-7df6f2f6748d>:21: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.*` instead of `tqdm._tqdm_notebook.*`
#   from tqdm._tqdm_notebook import tqdm_notebook

# %%
## Set your token
mytoken='Set your token here'
genius = Genius(mytoken)

# %%
## Lista dos artistas
list_art=["Criolo", "Fernandinho","Pitty","Os Barões da Pisadinha"]

# %%
# %%time
## Loop para recuperar as letras de todas as músicas de cada artista
for i in range(len(list_art)):
    artist = genius.search_artist(list_art[i], sort="title")
    artist.save_lyrics()
# Out:
# Searching for songs by Criolo...
#
# Song 1: "4 da Manhã"
# Song 2: "Agradeço a Quem Devo (Escuta)"
# Song 3: "Ainda Há Tempo"
# Song 4: "Andar como terrorista"
# Song 5: "Aprendiz"
# Song 6: "A Real"
# Song 7: "Até Me Emocionei"
# Song 8: "Boca de Lobo"
# Song 9: "Boca Fofa"
# Song 10: "Bogotá"
# Song 11: "Breáco"
# Song 12: "Calçada"
# Song 13: "Cálice"
# Song 14: "Capitulo 4, versiculo 3 - live"
# Song 15: "Cartão de Visita"
# Song 16: "Casa de Mãe (Acústico)"
# Song 17: "Casa de Papelão"
# Song 18: "Casca De Ovo"
# Song 19: "Cerol"
# Song 20: "Chuva Ácida"
# Song 21: "Cigano"
# Song 22: "Cóccix-ência"
# Song 23: "Convoque Seu Buda"
# Song 24: "Cria de Favela"
# Song 25: "Demorô"
# Song 26: "Demorô - live"
# Song 27: "Dilúvio de Solidão"
# Song 28: "Doum"
# Song 29: "Duas de Cinco"
# Song 30: "É o Teste"
# Song 31: "Espiral de Ilusão"
# Song 32: "Esquiva da Esgrima"
# Song 33: "Etérea"
# Song 34: "Fellini"
# Song 35: "Fermento Pra Massa"
# Song 36: "Filha do Maneco"
# Song 37: "Fio De Prumo (Padê Onã)"
# Song 38: "Freguês da Meia Noite"
# Song 39: "Gelo No Inferno"
# Song 40: "Grajauex"
# "High on Nothing" is not valid. Skipping.
# Song 41: "Hora da Decisão"
# Song 42: "Intro (Ainda Há Tempo)"
# Song 43: "Lantejoula"
# Song 44: "Lá Vem Você"
# Song 45: "Leia todas as letras de ’Espiral de Ilusão’, novo disco de Criolo"
# Song 46: "Língua Felina"
# Song 47: "Linha de Frente"
# Song 48: "Lion Man"
# Song 49: "Mariô"
# Song 50: "Me Dê Motivo"
# Song 51: "Menino Mimado"
# Song 52: "Morto Vivo"
# Song 53: "Não Existe Amor em SP"
# Song 54: "Nas Águas"
# Song 55: "No Sapatinho"
# Song 56: "Pé de Breque"
# Song 57: "Pegue Pra Ela"
# Song 58: "Plano de Voo"
# Song 59: "Povo Guerreiro"
# Song 60: "Que Bloco É Esse?"
# Song 61: "Rap é Forte"
# Song 62: "Roba A Cena"
# Song 63: "Sabedoria de Ébano"
# Song 64: "Samba Sambei"
# Song 65: "Samba Sambei (Dub Mix)"
# Song 66: "Subirusdoistiozin"
# Song 67: "Sucrilhos"
# Song 68: "Tô Pra Vê"
# Song 69: "Tô Pra Ver"
# Song 70: "Vai Ser Assim"
# Song 71: "Vasilhame"
# Song 72: "Vem Comigo"
# Song 73: "Voz e violão"
# Done. Found 73 songs.
# Wrote Lyrics_Criolo.json.
# Searching for songs by Fernandinho...
#
# Song 1: "A alegria do senhor"
# Song 2: "Abundante Chuva"
# Song 3: "Agindo deus"
# Song 4: "Ainda que a Figueira"
# Song 5: "Ao Deus De Abraão"
# Song 6: "Baruk Raba"
# Song 7: "Batiza-me"
# Song 8: "Caia Fogo"
# Song 9: "Canta Alegremente"
# "Chorem" is not valid. Skipping.
# Song 10: "Como eu te amo"
# "Como Eu Te Amo (Em Casa)" is not valid. Skipping.
# Song 11: "Derrama"
# Song 12: "Desde A Antiguidade"
# Song 13: "Deus Não Está Morto"
# Song 14: "Deus Tem o Melhor Pra Mim"
# Song 15: "Dono do Mundo"
# Song 16: "Eis-me Aqui"
# "É Tempo de Abrir o Coração (Ao Vivo)" is not valid. Skipping.
# Song 17: "Eu fui comprado"
# Song 18: "Eu Vou Abrir O Meu Coração"
# Song 19: "Eu Vou Subir A Montanha"
# "Eu Vou Subir A Montanha (Em Casa)" is not valid. Skipping.
# Song 20: "Faz Chover"
# Song 21: "Fogo Consumidor"
# "Fogo Consumidor (Em Casa)" is not valid. Skipping.
# Song 22: "Formoso És"
# Song 23: "Galileu"
# Song 24: "Galileu (Remix)"
# Song 25: "Geração De Samuel"
# "Geração de Samuel (Em Casa)" is not valid. Skipping.
# Song 26: "Grande É O Senhor"
# Song 27: "Grandes Coisas (God of This City)"
# Song 28: "Há Um Rio"
# Song 29: "Infinitamente mais"
# Song 30: "Já Estou Crucificado"
# Song 31: "Jesus, filho de deus"
# Song 32: "Luz do Mundo"
# Song 33: "Mais Alto"
# Song 34: "Me Leva"
# Song 35: "Mil Cairão"
# Song 36: "Nada Além do Sangue"
# Song 37: "Não Há Outro"
# Song 38: "Não mais escravo"
# Song 39: "O hino"
# Song 40: "O Meu Deus É Soberano"
# Song 41: "Pai de Multidões"
# Song 42: "Perdão"
# Song 43: "Quero Te Obedecer"
# Song 44: "Santo (Ao Vivo)"
# Song 45: "Sara-me"
# Song 46: "Semelhantes A Jesus"
# Song 47: "Se Não For Pra Te Adorar"
# Song 48: "Seu Sangue"
# Song 49: "Te Adorar"
# Song 50: "Temos Que Ser Um"
# Song 51: "Teus sonhos"
# Song 52: "Todas As Coisas/Tudo Entregarei"
# Song 53: "Totalmente Teu"
# "Totalmente Teu (Em Casa)" is not valid. Skipping.
# Song 54: "Tua Fidelidade"
# Song 55: "Tudo e possivel"
# Song 56: "Uma coisa peo ao senhor"
# Song 57: "Uma Nova História"
# Song 58: "Um Dia em Tua Casa"
# Song 59: "Vento Impetuoso"
# "Vento Impetuoso / Eu Navegarei" is not valid. Skipping.
# Done. Found 59 songs.
# Wrote Lyrics_Fernandinho.json.
# Searching for songs by Pitty...
#
# Song 1: "8 ou 80"
# Song 2: "8 ou 80 - Ao Vivo"
# Song 3: "Aahhh!"
# Song 4: "Admirável Chip Novo"
# Song 5: "Admirável Chip Novo - Ao Vivo"
# Song 6: "Admirável Chip Novo - Ao Vivo (2019)"
# Song 7: "Agora Só Falta Você"
# Song 8: "Água Contida"
# Song 9: "Água Contida - Ao Vivo"
# Song 10: "A Massa"
# Song 11: "Anacrônico"
# Song 12: "Anacrônico - Ao Vivo"
# Song 13: "A Saideira"
# Song 14: "A Saideira - Ao Vivo"
# Song 15: "A Sombra"
# Song 16: "Azul (Vinheta)"
# Song 17: "Bahia Blues"
# Song 18: "Bahia Blues - Ao Vivo"
# Song 19: "Bicho Solto"
# Song 20: "Bicho Solto - Ao Vivo"
# Song 21: "Boca Aberta"
# Song 22: "Brinquedo Torto"
# Song 23: "Brinquedo Torto - Ao Vivo"
# Song 24: "Comum de Dois"
# Song 25: "Comum de Dois - Ao Vivo"
# Song 26: "Contramão"
# Song 27: "Dançando - Ao Vivo"
# Song 28: "Deixa Ela Entrar"
# Song 29: "Déjà Vu"
# Song 30: "Déjá Vu - Ao Vivo"
# Song 31: "Déjà Vu (Demo 2003)"
# Song 32: "Desconstruindo Amélia"
# Song 33: "Desconstruindo Amélia - Ao Vivo"
# Song 34: "Dê um Rolê"
# Song 35: "Deus Lhe Pague"
# Song 36: "De Você"
# Song 37: "De Você - Ao Vivo"
# Song 38: "Digging The Grave"
# Song 39: "Do Mesmo Lado"
# Song 40: "Emboscada"
# Song 41: "Emboscada - Ao Vivo"
# Song 42: "Equalize"
# Song 43: "Equalize - Ao Vivo"
# Song 44: "Equalize - Ao Vivo (2019)"
# Song 45: "Eu Sou Egoísta"
# Song 46: "Fracasso"
# Song 47: "Fracasso - Ao Vivo"
# Song 48: "Go With The Flow"
# Song 49: "Guerreiros São Guerreiros"
# Song 50: "Ignorin’ U"
# Song 51: "Ignorin’u - Ao Vivo"
# Song 52: "I Wanna Be"
# Song 53: "I Wanna Be - Ao Vivo"
# Song 54: "Just Now (Só Agora)"
# Song 55: "Lado de Lá"
# Song 56: "Malditos Cromossomos - Ao Vivo"
# Song 57: "Máscara"
# Song 58: "Máscara - Ao Vivo"
# Song 59: "Máscara / Bonecas Pretas  - Ao Vivo"
# Song 60: "Me Adora"
# Song 61: "Me Adora - Ao Vivo"
# Song 62: "Me Adora - Ao Vivo (2019)"
# Song 63: "Medo"
# Song 64: "Medo - Ao Vivo"
# Song 65: "Memórias"
# Song 66: "Memórias - Ao Vivo"
# Song 67: "Memórias - Ao Vivo (2019)"
# Song 68: "Motor"
# Song 69: "Motor - Ao Vivo"
# Song 70: "Na Sua Estante"
# Song 71: "Na Sua Estante - Ao Vivo"
# Song 72: "Na Sua Estante - Ao Vivo (2019)"
# Song 73: "Na Tela"
# Song 74: "Ninguém é de Ninguém"
# Song 75: "Ninguém É de Ninguém - Ao Vivo"
# Song 76: "Ninguém é de Ninguém - Kishimoto Remix"
# Song 77: "Ninguém é de Ninguém - Marcelinho da Lua Remix"
# Song 78: "No Escuro"
# Song 79: "No Escuro - Ao Vivo"
# Song 80: "Noite Inteira"
# Song 81: "Noite Inteira - Ao Vivo"
# Song 82: "Noite Inteira - BADSISTA Remix"
# Song 83: "Noite Inteira - Brabo Remix"
# Song 84: "Noite Inteira - Deeplick Remix"
# Song 85: "Olho Calmo"
# Song 86: "O Lobo"
# Song 87: "O Lobo - Ao Vivo"
# Song 88: "O Muro"
# Song 89: "Para o Grande Amor"
# Song 90: "Para o Grande Amor - Ao Vivo"
# Song 91: "Pequena Morte"
# Song 92: "Pouco"
# Song 93: "Pra Onde Ir"
# Song 94: "Pra Onde Ir - Ao Vivo"
# Song 95: "Pulsos - Ao Vivo"
# Song 96: "Quem Vai Queimar?"
# Song 97: "Quem Vai Queimar? - Ao Vivo"
# Song 98: "Querer Depois"
# Song 99: "Questão de Ordem"
# Song 100: "Rato na Roda"
# Song 101: "Rato na Roda - Ao Vivo"
# Song 102: "Redimir"
# Song 103: "Redimir - Ao Vivo"
# Song 104: "Roda"
# Song 105: "Roda - Ao Vivo"
# Song 106: "Roda - Pupillo Remix"
# Song 107: "Romeu"
# Song 108: "Saudade (Vinheta)"
# Song 109: "Semana Que Vem"
# Song 110: "Semana Que Vem - Ao Vivo"
# Song 111: "Senhor das Moscas - Ao Vivo"
# Song 112: "Serpente"
# Song 113: "Serpente - Ao Vivo"
# Song 114: "SETEVIDAS"
# Song 115: "Setevidas - Ao Vivo"
# Song 116: "Seu Mestre Mandou"
# Song 117: "Seu Mestre Mandou - Ao Vivo"
# Song 118: "Se Você Pensa"
# Song 119: "Só Agora"
# Song 120: "Só Agora - Ao Vivo"
# Song 121: "Sob o Sol"
# Song 122: "Só de Passagem"
# Song 123: "Só de Passagem - Ao Vivo"
# Song 124: "Sol Quadrado"
# Song 125: "Sol Quadrado - Ao Vivo"
# Song 126: "Stay Away"
# Song 127: "Suas Armas"
# Song 128: "Submersa"
# Song 129: "Te Conecta"
# Song 130: "Te Conecta / Tudo Me Faz Sentido - Ao Vivo"
# Song 131: "Tempo de Brincar"
# Song 132: "Temporal"
# Song 133: "Teto de Vidro"
# Song 134: "Teto de Vidro - Ao Vivo (2019)"
# Song 135: "Tiro ao Álvaro"
# Song 136: "Todos Estão Mudos"
# Song 137: "Todos Estão Mudos - Ao Vivo"
# Song 138: "Trapézio"
# Song 139: "Trapézio - Ao Vivo"
# Song 140: "Um Leão"
# Done. Found 140 songs.
# Wrote Lyrics_Pitty.json.
# Searching for songs by Os Barões da Pisadinha...
# Song 1: "Agora Eu Pego Mesmo"
# Song 2: "American Pie"
# Song 3: "Amor da Despedida"
# Song 4: "Amor Falso"
# Song 5: "A Roça ou A Cidade"
# Song 6: "Atrasadinha"
# Song 7: "Baby Volta Pro Seu Nego"
# Song 8: "Basta Você Me Ligar"
# Song 9: "Batom de Ouro"
# Song 10: "Bebe e Vem Me Procurar"
# Song 11: "Bebezinha"
# Song 12: "Beijo do Vampiro"
# Song 13: "Cabeça Voando"
# Song 14: "Casa de Praia"
# Song 15: "Chama as Vaqueirinhas"
# Song 16: "Chupadinha"
# Song 17: "Com Ele é Cinema, Comigo é Cama"
# Song 18: "Cornetinha"
# Song 19: "Dançar Forró Beijando"
# Song 20: "Desce do Cavalo"
# Song 21: "Dim Dim Dim"
# Song 22: "DNA do Interior"
# Song 23: "Ela Não Larga Eu"
# Song 24: "Escondido Dos Seus Pais"
# Song 25: "Espinhaço do Véi"
# Song 26: "Esquema Preferido"
# Song 27: "Eu Acho Que Não"
# Song 28: "Eu Fui Pra Terminar"
# Song 29: "Fake News"
# Song 30: "Fala Comigo Bebê (Ao Vivo)"
# Song 31: "Festa na Roça"
# Song 32: "Fiat Toro"
# Song 33: "Filho do Mato"
# Song 34: "Flecha Louca"
# Song 35: "Fuleragem"
# Song 36: "Galanteador"
# Song 37: "Galera do Interior"
# Song 38: "Gol Quadrado"
# Song 39: "Gordinho do Amor"
# Song 40: "Já Que Me Ensinou a Beber"
# Song 41: "Jogo de Amor"
# Song 42: "Liga Pra Sua Ex"
# Song 43: "Liga Pro 190"
# Song 44: "Linda demais"
# Song 45: "Linguinha"
# Song 46: "Mamãe Que É Mamãe"
# Song 47: "Meia Noite (Cê Tem Meu WhatsApp)"
# Song 48: "Mordidinha"
# Song 49: "My Baby"
# Song 50: "Não Me Deu Moral"
# Song 51: "Não Troco Por Nada"
# Song 52: "Nota Dez"
# Song 53: "Novinha Me Perguntou"
# Song 54: "Novinha Pode Pá"
# Song 55: "Nunca Vai Ser Eu"
# Song 56: "Ô Bebê"
# Song 57: "Oi e Tchau"
# Song 58: "Piseiro Estourou (Ao Vivo)"
# Song 59: "Quando a Saudade Bater"
# Song 60: "Quem É Seu Favorito"
# Song 61: "Quem me Colocou pra Beber"
# Song 62: "Quem Me Dera"
# Song 63: "Quero Sentir De Novo"
# Song 64: "Quero Ver é Me Esquecer"
# Song 65: "Recairei"
# Song 66: "Resquícios de Mim"
# Song 67: "Salto 15"
# Song 68: "Saudade dos Parceiros"
# Song 69: "Se Mordendo De Raiva"
# Song 70: "Seu Bebê Tá Bebo"
# Song 71: "Sexta-Feira"
# Song 72: "Sexta Feira Rotineira"
# Song 73: "Só Falta Você Aceitar"
# Song 74: "Som da Roça"
# Song 75: "Só Quer Vrau"
# Song 76: "Sou Eu"
# Song 77: "Sou Favela"
# Song 78: "Surto de Amor"
# Song 79: "SW4 Preta"
# Song 80: "Tá Complicado"
# Song 81: "Tá Rocheda"
# Song 82: "Tá Tum Tum"
# Song 83: "Tipo iFood"
# Song 84: "Vaqueiro Atualizado"
# Song 85: "Vaqueiro da Zona Rural"
# Song 86: "Voltei Pra Vaquejada"
# Song 87: "Vou Virar Fazendeiro"
# Song 88: "Zero Saudade"
# Done. Found 88 songs.
# Wrote Lyrics_OsBarõesdaPisadinha.json.
# Wall time: 14min 58s

# %%
## Carregando todos arquivos json que estão armazenados localmente
path_to_json = 'inserir aqui o caminho dos dados'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
print(json_files)

## Setting novo dataframe
dados=[]
dados = pd.DataFrame(dados, columns=['artist','full_title','lyrics','lyrics_state'])

## Armazenando os dados em único dataframe
for i in range(len(json_files)):
    ## Open JSon file with lyrics saved
    f = open (json_files[i], "r")
    # Reading from file
    data = json.loads(f.read())
    df = pd.DataFrame(data['songs'])
    df=df[["artist","full_title","lyrics","lyrics_state"]]
    dados=dados.append(df)
# Out:
# ['Lyrics_Criolo.json', 'Lyrics_Fernandinho.json', 'Lyrics_OsBarõesdaPisadinha.json', 'Lyrics_Pitty.json']

# %% [markdown]
# ## 2.1 Pré processamento dos dados
# Para a etapa de preprocessamento de dados foram utilizadas várias estratégias que foram apresendidas ao longo deste caminho de aprendizagem sobre NLP. Portanto, embora algumas estratégias sejam análogas, optou-se por mante-las nesse trabalho a fim de evidenciar as várias formas existentes de pre-prococessamento de textos. <br>

# %%
## Reset index
dados= dados.reset_index(drop=True)
dados
# Out:
#      artist                               full_title  \
# 0    Criolo                     4 da Manhã by Criolo
# 1    Criolo  Agradeço a Quem Devo (Escuta) by Criolo
# 2    Criolo                 Ainda Há Tempo by Criolo
# 3    Criolo          Andar como terrorista by Criolo
# 4    Criolo                       Aprendiz by Criolo
# ..      ...                                      ...
# 355   Pitty               Todos Estão Mudos by Pitty
# 356   Pitty     Todos Estão Mudos - Ao Vivo by Pitty
# 357   Pitty                        Trapézio by Pitty
# 358   Pitty              Trapézio - Ao Vivo by Pitty
# 359   Pitty                         Um Leão by Pitty
#
#                                                 lyrics lyrics_state
# 0    Letra verificada de "4 da Manhã" com Criolo\n[...     complete
# 1    Ê, maior é Deus, pequeno sou eu\nO que eu tenh...     complete
# 2    [Verso 1]\nVocê quer saber, então vou te falar...     complete
# 3    [Refrão]\nDesta vez o canhão não será necessár...     complete
# 4    [Refrão 2x]\nEu quero algo de bom pra você e p...     complete
# ..                                                 ...          ...
# 355  [Letra de "Todos Estão Mudos", de Pitty]\n\n[V...     complete
# 356  [Letra de "Todos Estão Mudos - Ao Vivo", de Pi...     complete
# 357  [Letra de "Trapézio", de Pitty]\n\nEu queria e...     complete
# 358  [Letra de "Trapézio - Ao Vivo", de Pitty]\n\nE...     complete
# 359  [Letra de "Um Leão", de Pitty]\n\n[Verso 1]\nE...     complete
#
# [360 rows x 4 columns]

# %%
dados['lyrics'][2]
# Out:
# '[Verso 1]\nVocê quer saber, então vou te falar\nPorque as pessoas sadias adoecem\nBem alimentadas ou não, porque perecem?\nTudo está guardado na mente\nO que você quer nem sempre condiz com o que o outro sente\nEu tô falando é de atenção\nQue dá cola ao coração e faz marmanjo chorar\nSe faltar um simples sorriso\nOu às vezes um olhar\nE que se vem da pessoa errada não conta\nA amizade é importante, mas o amor escancara a tampa\nE o que te faz feliz também provoca a dor\nA cadência do surdo no coro que se forjou\nE aliás, cá pra nós, até o mais desandado\nDá um tempo na função quando percebe que é amado\nE as pessoas se olham e não se falam\nSe esbarram na rua e se maltratam\nUsam a desculpa de que nem Cristo agradou\nFalô, você vai querer mesmo se comparar com o Senhor?\n\n[Refrão]\nAs pessoas não são más\nElas só estão perdidas\nAinda há tempo\nNão quero ver\nVocê triste assim não\nQue a minha música possa\nTe levar amor\nNão quero ver\nVocê triste assim não\nQue a minha música possa\nTe levar amor\n\n[Verso 2]\nExemplo não sou, tô longe de ser\nCidadão comum com vontade de vencer\nRap: que energia é essa?\nUm dom, um carma, uma dívida, uma prece\nE infelizmente tem\nAlguns que desmerecem\nÉ tanta coisa na cabeça, sai fora, me esquece\nSem saúde, sem paz, o nosso povo padece\nNo Grajaú, só, num frio de dar dó\nEsperando a lotação pra ir pro evento de rap\nLembrei de alguém que não está mais entre a gente\nA Dona Morte vem, carrega os manos na mó pressa\nUma estrela a mais no céu o rimador falta na Terra\nDeus sabe sempre o que tá fazendo\nMesmo sabendo disso eu sofro, vai vendo\nQuem tem noção das coisas sente o peso da maldade\nA cobrança é maior, inteligência traz vaidade\nQuem se deixou levar fraquejou, essa é a verdade\nAprenda com os erros, não se sinta um covarde\nNa praia, Jesus me carregou no colo\nEu vi um par de pegadas, não entendi o óbvio\nQue o fardo não é maior do que eu posso carregar\nSe a vida é um jogo então vamo ganhar\n\n[Refrão]\nAs pessoas não são más\nElas só estão perdidas\nAinda há tempo\nNão quero ver\nVocê triste assim não\nQue a minha música possa\nTe levar amor\nNão quero ver\nVocê triste assim não\nQue a minha música possa\nTe levar amor\n\n[Verso 3]\nEntão me fala, fala, pergunta que não cala\nSe o rap é pro bem, então por que tanta gente atrapalha?\nCom o poder da mente a maldade paraliso\nO mecanismo do sistema é sugar sua alma vivo\nSeu sangue, seu suor, são só um detalhe nisso\nChuva ácida será bem pior que um lançamento de um míssil\nEntre o céu e o inferno, no Grajaú me localizo\nFlutuando na hipocrisia do lodo e do fascismo\nPronto pra rimar, um doido criolo mestiço\nEu não sou preto, eu não sou branco, eu sou do rap, eu sou bem isso\nQuem perdeu a noção por luxúria tá perdido\nQuem perdeu a razão por dinheiro eu nem te digo\nSaúde e microfone é a fórmula de que preciso\nPorque se o rap tá comigo eu não me sinto excluído\n\n[Refrão]\nAs pessoas não são más\nElas só estão perdidas\nAinda há tempo\nNão quero ver\nVocê triste assim não\nQue a minha música possa\nTe levar amor\nNão quero ver\nVocê triste assim não\nQue a minha música possa\nTe levar amor\nNão quero ver\nVocê triste assim não\nQue a minha música possa\nTe levar amor\nNão quero ver\nVocê triste assim não\nQue a minha música possa\nTe levar amor'

# %%
## Criando uma nova coluna para armazenar o texto que será limpo
## Substituir todos os textos dentro de parênteses/colchetes
dados['letra_limpa']=dados['lyrics']
for i in range(len(dados)):
    dados['letra_limpa'][i]=re.sub("[\(\[].*?[\)\]]", "", dados['letra_limpa'][i])

# %%
dados.head()
# Out:
#    artist                               full_title  \
# 0  Criolo                     4 da Manhã by Criolo
# 1  Criolo  Agradeço a Quem Devo (Escuta) by Criolo
# 2  Criolo                 Ainda Há Tempo by Criolo
# 3  Criolo          Andar como terrorista by Criolo
# 4  Criolo                       Aprendiz by Criolo
#
#                                               lyrics lyrics_state  \
# 0  Letra verificada de "4 da Manhã" com Criolo\n[...     complete
# 1  Ê, maior é Deus, pequeno sou eu\nO que eu tenh...     complete
# 2  [Verso 1]\nVocê quer saber, então vou te falar...     complete
# 3  [Refrão]\nDesta vez o canhão não será necessár...     complete
# 4  [Refrão 2x]\nEu quero algo de bom pra você e p...     complete
#
#                                          letra_limpa
# 0  Letra verificada de "4 da Manhã" com Criolo\n\...
# 1  Ê, maior é Deus, pequeno sou eu\nO que eu tenh...
# 2  \nVocê quer saber, então vou te falar\nPorque ...
# 3  \nDesta vez o canhão não será necessário\nAnda...
# 4  \nEu quero algo de bom pra você e pra mim\nE p...

# %%
## Métodos de preprocessamento de texto, porém com saídas distintas
def pre_processamento_texto(corpus):
    corpus_alt=re.findall(r"\w+(?:'\w+)?|[^\w\s]",corpus)
    #Lowcase
    corpus_alt=[t.lower() for t in corpus_alt]
    #remove stopwords"
    portugues_stops=stopwords.words('portuguese')
    corpus_alt=[t for t in corpus_alt if t not in portugues_stops]
    #remove números
    corpus_alt=[re.sub(r'\d','',t) for t in corpus_alt]
    #remove pontuação
    corpus_alt=[t for t in corpus_alt if t not in string.punctuation]
    #remove acentos
    corpus_alt=[unidecode(t) for t in corpus_alt]
    
    return corpus_alt

def pre_processamento_texto_return_str(corpus):
    #print("Documento")
    #print("#tokenização")
    corpus_alt=re.findall(r"\w+(?:'\w+)?|[^\w\s]",corpus)
    #Lowcase
    corpus_alt=[t.lower() for t in corpus_alt]
    #print("#remove stopwords")
    portugues_stops=stopwords.words('portuguese')
    corpus_alt=[t for t in corpus_alt if t not in portugues_stops]
    #print("#remove pontuação")
    corpus_alt=[t for t in corpus_alt if t not in string.punctuation]
   # print("#remove numeros")
    corpus_alt=[re.sub(r'\d','',t) for t in corpus_alt]

    corpus_alt_str=' '.join(corpus_alt)

      
    return corpus_alt_str

# %% [markdown]
# ## 2.2 Representação Textual - Bigramas
# Após a utilização de um método para realização do preprocessamento dos dados, sereá realizada a representação textual das letras de músicas por meio do cálculo dos bigramas.

# %%
letras_list = dados['letra_limpa'].values.tolist()
documento_limpo= [pre_processamento_texto(doc)  for doc in letras_list]
model_corpus_phrases = gensim.models.Phrases(documento_limpo, min_count=2)
#calulando os bigrams do corpus processado
bigram_corpus = model_corpus_phrases[documento_limpo]
bigram_corpus[2]
# Out:
# ['quer_saber',
#  'entao',
#  'vou',
#  'falar',
#  'porque',
#  'pessoas',
#  'sadias',
#  'adoecem',
#  'bem',
#  'alimentadas',
#  'porque',
#  'perecem',
#  'tudo',
#  'guardado',
#  'mente',
#  'quer',
#  'sempre',
#  'condiz',
#  'outro',
#  'sente',
#  'to_falando',
#  'atencao',
#  'da',
#  'cola',
#  'coracao',
#  'faz',
#  'marmanjo',
#  'chorar',
#  'faltar',
#  'simples',
#  'sorriso',
#  'vezes',
#  'olhar',
#  'vem',
#  'pessoa',
#  'errada',
#  'conta',
#  'amizade',
#  'importante',
#  'amor',
#  'escancara',
#  'tampa',
#  'faz',
#  'feliz',
#  'provoca',
#  'dor',
#  'cadencia',
#  'surdo',
#  'coro',
#  'forjou',
#  'alias',
#  'ca',
#  'pra',
#  'desandado',
#  'da',
#  'tempo',
#  'funcao',
#  'percebe',
#  'amado',
#  'pessoas',
#  'olham',
#  'falam',
#  'esbarram',
#  'rua',
#  'maltratam',
#  'usam',
#  'desculpa',
#  'cristo',
#  'agradou',
#  'falo',
#  'vai',
#  'querer',
#  'comparar',
#  'senhor',
#  'pessoas_mas',
#  'perdidas_ainda',
#  'tempo',
#  'quero_ver',
#  'triste_assim',
#  'musica_possa',
#  'levar_amor',
#  'quero_ver',
#  'triste_assim',
#  'musica_possa',
#  'levar_amor',
#  'exemplo',
#  'to',
#  'longe',
#  'ser',
#  'cidadao',
#  'comum',
#  'vontade',
#  'vencer',
#  'rap',
#  'energia',
#  'dom',
#  'carma',
#  'divida',
#  'prece',
#  'infelizmente',
#  'alguns',
#  'desmerecem',
#  'tanta',
#  'coisa',
#  'cabeca',
#  'sai',
#  'esquece',
#  'saude',
#  'paz',
#  'povo',
#  'padece',
#  'grajau',
#  'frio',
#  'dar',
#  'do',
#  'esperando',
#  'lotacao',
#  'pra',
#  'ir',
#  'pro',
#  'evento',
#  'rap',
#  'lembrei',
#  'alguem',
#  'gente',
#  'dona',
#  'morte',
#  'vem',
#  'carrega',
#  'manos',
#  'mo',
#  'pressa',
#  'estrela',
#  'ceu',
#  'rimador',
#  'falta',
#  'terra_deus',
#  'sabe',
#  'sempre',
#  'ta',
#  'fazendo',
#  'sabendo',
#  'disso',
#  'sofro',
#  'vai',
#  'vendo',
#  'nocao',
#  'coisas',
#  'sente',
#  'peso',
#  'maldade',
#  'cobranca',
#  'maior',
#  'inteligencia',
#  'traz',
#  'vaidade',
#  'deixou',
#  'levar',
#  'fraquejou',
#  'verdade',
#  'aprenda',
#  'erros',
#  'sinta',
#  'covarde',
#  'praia',
#  'jesus',
#  'carregou',
#  'colo',
#  'vi',
#  'par',
#  'pegadas',
#  'entendi',
#  'obvio',
#  'fardo',
#  'maior',
#  'posso',
#  'carregar',
#  'vida',
#  'jogo',
#  'entao',
#  'vamo',
#  'ganhar',
#  'pessoas_mas',
#  'perdidas_ainda',
#  'tempo',
#  'quero_ver',
#  'triste_assim',
#  'musica_possa',
#  'levar_amor',
#  'quero_ver',
#  'triste_assim',
#  'musica_possa',
#  'levar_amor',
#  'entao',
#  'fala',
#  'fala',
#  'pergunta',
#  'cala',
#  'rap',
#  'pro',
#  'bem',
#  'entao',
#  'tanta_gente',
#  'atrapalha',
#  'poder',
#  'mente',
#  'maldade',
#  'paraliso',
#  'mecanismo',
#  'sistema',
#  'sugar',
#  'alma',
#  'vivo',
#  'sangue',
#  'suor',
#  'detalhe',
#  'nisso',
#  'chuva',
#  'acida',
#  'bem',
#  'pior',
#  'lancamento',
#  'missil',
#  'ceu',
#  'inferno',
#  'grajau',
#  'localizo',
#  'flutuando',
#  'hipocrisia',
#  'lodo',
#  'fascismo',
#  'pronto',
#  'pra',
#  'rimar',
#  'doido',
#  'criolo',
#  'mestico',
#  'preto_branco',
#  'rap',
#  'bem',
#  'perdeu',
#  'nocao',
#  'luxuria',
#  'ta',
#  'perdido',
#  'perdeu',
#  'razao',
#  'dinheiro',
#  'digo',
#  'saude',
#  'microfone',
#  'formula',
#  'preciso',
#  'porque',
#  'rap',
#  'ta',
#  'comigo',
#  'sinto',
#  'excluido',
#  'pessoas_mas',
#  'perdidas_ainda',
#  'tempo',
#  'quero_ver',
#  'triste_assim',
#  'musica_possa',
#  'levar_amor',
#  'quero_ver',
#  'triste_assim',
#  'musica_possa',
#  'levar_amor',
#  'quero_ver',
#  'triste_assim',
#  'musica_possa',
#  'levar_amor',
#  'quero_ver',
#  'triste_assim',
#  'musica_possa',
#  'levar_amor']

# %% [markdown]
# ## 2.3  Bag of Words

# %%
tqdm_notebook.pandas()
dados["text_sem_stopwords"]=dados['letra_limpa'].progress_apply(lambda x: pre_processamento_texto_return_str(x))
vec_bag=CountVectorizer()
X_bag=vec_bag.fit_transform(dados['text_sem_stopwords'])
# Out:
#   0%|          | 0/360 [00:00<?, ?it/s]

# %%
dados['text_sem_stopwords']
# Out:
# 0      letra verificada  manhã criolo quatro manhã ac...
# 1      ê maior deus pequeno deus deu dou deus deu ê m...
# 2      quer saber então vou falar porque pessoas sadi...
# 3      desta vez canhão necessário andar terrorista f...
# 4      quero algo bom pra pra mim pra outra pessoa po...
#                              ...
# 355    ouço clamores sinal frases outrora gritos supr...
# 356    ouço clamores sinal frases outrora gritos supr...
# 357    queria dizer diferente todo mundo sente conseg...
# 358    queria dizer diferente todo mundo sente conseg...
# 359    ei bem faz favor traz alguém saiba amor porém ...
# Name: text_sem_stopwords, Length: 360, dtype: object

# %%
X_bag
# Out:
# <360x6432 sparse matrix of type '<class 'numpy.int64'>'
# 	with 20362 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## 2.4 Embedding
# Utilizando um embedding treinado

# %%
path = "inserir o caminho aqui"
word_vectors = gensim.models.KeyedVectors.load_word2vec_format(path, binary=False)

# %%
#def get_embedding(frase):
#  return np.mean(np.array([word_vectors[palavra] for palavra in frase if palavra in word_vectors.key_to_index ]),axis=0)

# %%
#dados["text_sem_token"]=dados["letra_limpa"].progress_apply(lambda x: pre_processamento_texto(x))
#x_emb=dados["text_sem_token"].progress_apply(lambda x: get_embedding(x))
# Out:
#   0%|          | 0/360 [00:00<?, ?it/s]
#   0%|          | 0/360 [00:00<?, ?it/s]

# %% [markdown]
# Gerando os embeddings com o texto processado das letras de música

# %%
model = word2vec.Word2Vec(dados["text_sem_token"], min_count=10, workers=4, seed=123, sg=1,  window=5)

# %%
##Similaridade entre palavras
model.wv.similarity('teto','vidro') ## Duas palavras presentes na música "Teto de Vidro" da cantora Pitty
# Out:
# 0.99743986

# %%
def get_similares(model, palavra, max=5):
    palavras_similares=model.wv.most_similar(palavra, topn=5)
    palavras_similares=[p[0] for p in palavras_similares]
    palavras_similares.append(palavra)
    return palavras_similares

# %%
## Palavras similares de acordo com o modelo treinado
get_similares(model, "saudade")
# Out:
# ['querendo', 'liga', 'senao', 'vontade', 'zero', 'saudade']

# %%
## Importante!! Só é possível retornar palavras similares de acordo com as palavras utilizadas no treinamento do modelo
origem=[ "amor", "dor", "teto","deus","saber","sofrer"]

for p in origem:
    print(get_similares(model, p))
    print()
# Out:
# ['despedida', 'pes', 'vida', 'fala', 'cabeca', 'amor']
#
# ['feito', 'deixou', 'si', 'filhos', 'importa', 'dor']
#
# ['vidro', 'atire', 'primeira', 'pedra', 'tantas', 'teto']
#
# ['perdido', 'compara', 'vir', 'melhor', 'ouvirei', 'deus']
#
# ['deixar', 'acha', 'contar', 'sinto', 'ce', 'saber']
#
# ['morrer', 'tanto', 'traz', 'bola', 'biqueira', 'sofrer']

# %% [markdown]
# ## 3 Análise de Sentimentos
# Para essa etapa, serão utilizados dois tipos de algoritmos: <br>
# * Textblob
# * Afinn

# %%
result=[]
for i in range(len(dados)):
    sentence=TextBlob(dados.loc[i,"text_sem_stopwords"])
    result.append(sentence.sentiment)
dados['TextBlob_score']=result

# %%
afinn = Afinn()
result=[]
for i in range(len(dados)):
    result.append(afinn.score( dados.loc[i,"text_sem_stopwords"]))
dados['afinn_score']=result

# %%
## Retornar as letras/artista com Affin score menor do que zero
dados.loc[dados.afinn_score < 0,]
# Out:
#                      artist  \
# 3                    Criolo
# 10                   Criolo
# 24                   Criolo
# 27                   Criolo
# 29                   Criolo
# 36                   Criolo
# 60                   Criolo
# 66                   Criolo
# 160  Os Barões da Pisadinha
# 201  Os Barões da Pisadinha
# 211  Os Barões da Pisadinha
# 245                   Pitty
# 254                   Pitty
# 264                   Pitty
# 269                   Pitty
# 270                   Pitty
# 279                   Pitty
# 280                   Pitty
# 281                   Pitty
# 335                   Pitty
# 336                   Pitty
# 343                   Pitty
# 344                   Pitty
#
#                                             full_title  \
# 3                      Andar como terrorista by Criolo
# 10                                    Breáco by Criolo
# 24                                    Demorô by Criolo
# 27                                      Doum by Criolo
# 29                                 É o Teste by Criolo
# 36   Fio De Prumo (Padê Onã) by Criolo (Ft. Juçara ...
# 60             Rap é Forte by Criolo (Ft. Terra Preta)
# 66                                 Sucrilhos by Criolo
# 160                Fake News by Os Barões da Pisadinha
# 201         Seu Bebê Tá Bebo by Os Barões da Pisadinha
# 211            Tá Complicado by Os Barões da Pisadinha
# 245  Contramão by Pitty (Ft. Emmily Barreto & Tássi...
# 254                            Deus Lhe Pague by Pitty
# 264                            Eu Sou Egoísta by Pitty
# 269                                Ignorin' U by Pitty
# 270                       Ignorin’u - Ao Vivo by Pitty
# 279                                  Me Adora by Pitty
# 280                        Me Adora - Ao Vivo by Pitty
# 281                 Me Adora - Ao Vivo (2019) by Pitty
# 335                         Seu Mestre Mandou by Pitty
# 336               Seu Mestre Mandou - Ao Vivo by Pitty
# 343  Sol Quadrado by Pitty (Ft. Larissa Luz & Lazzo...
# 344  Sol Quadrado - Ao Vivo by Pitty (Ft. BaianaSys...
#
#                                                 lyrics lyrics_state  \
# 3    [Refrão]\nDesta vez o canhão não será necessár...     complete
# 10   [Refrão x2]\nSó pode falar de vida quem vive\n...     complete
# 24   [Intro]\nChorando\nNão, Criolo de novo não, nã...     complete
# 27   Coloquei a melhor roupa\nE as crianças mandei ...     complete
# 29   [Verso 1]\nA todo momento provar que sou tranq...     complete
# 36   [Refrão: Juçara Marçal]\nLaroyê Bará\nAbra o c...     complete
# 60   [Intro: Criolo]\nDo consumidor de uísque ao be...     complete
# 66   [Verso 1]\nCalçada pra favela, avenida pra car...     complete
# 160  Da minha boca só queria um beijo\nUsar o meu c...     complete
# 201  [Letra de "Seu Bebê Tá Bebo" com Os Barões da ...     complete
# 211  Mas eu não tenho carro, não tenho dinheiro\nEu...     complete
# 245  [Letra de "Contramão" com Pitty, Tássia Reis &...     complete
# 254  [Letra de "Deus Lhe Pague" com Pitty]\n\n[Vers...     complete
# 264  Se você acha que tem pouca sorte\nSe lhe preoc...     complete
# 269  [Letra de "Ignorin' U" com Pitty]\n\n[Refrão]\...     complete
# 270  [Letra de "Ignorin’u - Ao Vivo", de Pitty]\n\n...     complete
# 279  [Letra de "Me Adora", de Pitty]\n\n[Verso 1]\n...     complete
# 280  [Letra de "Me Adora - Ao Vivo", de Pitty]\n\n[...     complete
# 281  [Letra de "Me Adora - Ao Vivo", de Pitty]\n\n[...     complete
# 335  [Letra de "Seu Mestre Mandou", de Pitty]\n\nDá...     complete
# 336  [Letra de "Seu Mestre Mandou - Ao Vivo", de Pi...     complete
# 343  [Letra de "Sol Quadrado", de Pitty com Larissa...     complete
# 344  [Letra de "Sol Quadrado", de Pitty com Larissa...     complete
#
#                                            letra_limpa  \
# 3    \nDesta vez o canhão não será necessário\nAnda...
# 10   \nSó pode falar de vida quem vive\nSó pode fal...
# 24   \nChorando\nNão, Criolo de novo não, não quero...
# 27   Coloquei a melhor roupa\nE as crianças mandei ...
# 29   \nA todo momento provar que sou tranquilo\nNão...
# 36   \nLaroyê Bará\nAbra o caminho dos passos\nAbra...
# 60   \nDo consumidor de uísque ao bebedor de cajuín...
# 66   \nCalçada pra favela, avenida pra carro\nCéu p...
# 160  Da minha boca só queria um beijo\nUsar o meu c...
# 201  \n\n\nApaixonadinho\nSó casa, cinema, sorvete,...
# 211  Mas eu não tenho carro, não tenho dinheiro\nEu...
# 245  \n\n\nExiste outro lado do estrago que é feito...
# 254  \n\n\nPor esse pão pra comer, por esse chão pr...
# 264  Se você acha que tem pouca sorte\nSe lhe preoc...
# 269  \n\n\nI am ignorin' you\nI will ignore you\nI ...
# 270  \n\nI am ignoring you\nI will ignore you\nI am...
# 279  \n\n\nTantas decepções eu já vivi\nAquela foi ...
# 280  \n\n\nTantas decepções eu já vivi\nAquela foi ...
# 281  \n\n\nTantas decepções eu já vivi\nAquela foi ...
# 335  \n\nDá a pata, senta, deita\nNão respire, apag...
# 336  \n\nDá a pata, senta, deita\nNão respire, apag...
# 343  \n\n\nEles me disseram pra eu desistir\nDepois...
# 344  \n\nEles me disseram pra eu desistir\nDepois m...
#
#                                     text_sem_stopwords  \
# 3    desta vez canhão necessário andar terrorista f...
# 10   pode falar vida vive pode falar sofrimento sof...
# 24   chorando criolo novo quero então rá hô demorô ...
# 27   coloquei melhor roupa crianças mandei chamar t...
# 29   todo momento provar tranquilo ando cano pra co...
# 36   laroyê bará abra caminho passos abra caminho o...
# 60   consumidor uísque bebedor cajuína tamo junto c...
# 66   calçada pra favela avenida pra carro céu pra a...
# 160  boca queria beijo usar corpo pra matar desejo ...
# 201  apaixonadinho casa cinema sorvete sushi açaí a...
# 211  carro dinheiro fazendeiro sonhou cara sala aul...
# 245  existe outro lado estrago feito vendido perfei...
# 254  pão pra comer chão pra dormir certidão pra nas...
# 264  acha pouca sorte preocupa doença morte sente r...
# 269  i am ignorin you i will ignore you i am ignori...
# 270  i am ignoring you i will ignore you i am ignor...
# 279  tantas decepções vivi longe cruel silêncio pro...
# 280  tantas decepções vivi longe cruel silêncio pro...
# 281  tantas decepções vivi longe cruel silêncio pro...
# 335  dá pata senta deita respire apague luz vote mi...
# 336  dá pata senta deita respire apague luz vote mi...
# 343  disseram pra desistir falaram pra concordar ro...
# 344  disseram pra desistir falaram pra concordar ro...
#
#                                         text_sem_token  \
# 3    [desta, vez, canhao, necessario, andar, terror...
# 10   [pode, falar, vida, vive, pode, falar, sofrime...
# 24   [chorando, criolo, novo, quero, entao, ra, ho,...
# 27   [coloquei, melhor, roupa, criancas, mandei, ch...
# 29   [todo, momento, provar, tranquilo, ando, cano,...
# 36   [laroye, bara, abra, caminho, passos, abra, ca...
# 60   [consumidor, uisque, bebedor, cajuina, tamo, j...
# 66   [calcada, pra, favela, avenida, pra, carro, ce...
# 160  [boca, queria, beijo, usar, corpo, pra, matar,...
# 201  [apaixonadinho, casa, cinema, sorvete, sushi, ...
# 211  [carro, dinheiro, fazendeiro, sonhou, cara, sa...
# 245  [existe, outro, lado, estrago, feito, vendido,...
# 254  [pao, pra, comer, chao, pra, dormir, certidao,...
# 264  [acha, pouca, sorte, preocupa, doenca, morte, ...
# 269  [i, am, ignorin, you, i, will, ignore, you, i,...
# 270  [i, am, ignoring, you, i, will, ignore, you, i...
# 279  [tantas, decepcoes, vivi, longe, cruel, silenc...
# 280  [tantas, decepcoes, vivi, longe, cruel, silenc...
# 281  [tantas, decepcoes, vivi, longe, cruel, silenc...
# 335  [da, pata, senta, deita, respire, apague, luz,...
# 336  [da, pata, senta, deita, respire, apague, luz,...
# 343  [disseram, pra, desistir, falaram, pra, concor...
# 344  [disseram, pra, desistir, falaram, pra, concor...
#
#                                  TextBlob_score  afinn_score
# 3     (0.15833333333333333, 0.4666666666666666)        -10.0
# 10                                  (-0.4, 0.4)         -2.0
# 24                                   (0.5, 0.5)         -2.0
# 27                                   (0.0, 0.0)         -1.0
# 29                                   (0.5, 0.5)         -5.0
# 36                   (0.2, 0.30000000000000004)         -3.0
# 60                   (-0.6, 0.7666666666666666)        -11.0
# 66   (0.03333333333333333, 0.06666666666666667)         -2.0
# 160                                 (-0.5, 1.0)        -12.0
# 201                                  (0.0, 0.0)        -12.0
# 211                                  (0.0, 0.0)         -2.0
# 245   (0.14285714285714285, 0.5428571428571428)         -4.0
# 254                                  (0.0, 0.0)         -1.0
# 264                                  (0.0, 0.0)         -1.0
# 269   (0.05909090909090908, 0.6348484848484848)        -27.0
# 270   (0.05909090909090908, 0.6348484848484848)        -27.0
# 279                                 (-1.0, 1.0)         -3.0
# 280                                 (-1.0, 1.0)         -3.0
# 281                                 (-1.0, 1.0)         -3.0
# 335                                  (0.0, 0.0)         -1.0
# 336                                  (0.0, 0.0)         -1.0
# 343                                 (-0.6, 1.0)         -6.0
# 344                                 (-0.6, 1.0)         -6.0

# %%
## Menor score
print(dados['lyrics'][270])
# Out:
# [Letra de "Ignorin’u - Ao Vivo", de Pitty]
#
# I am ignoring you
# I will ignore you
# I am ignoring you
# I will ignore you
# Cause your heart is so
# Full of this shit
# And I will ignore you
#
# Don't bring me your sorrows
# Don't bring me your jealousy
# Don't drown me in your mood
# That kind of thing you do
# Cause I was not born to be
# The princess up the tower
# Oh, you can't keep me
# Quiet and tied in this bloody cage
#
# I am ignoring you
# I will ignore you
# I am ignoring you
# I will ignore you
# Cause your heart is so
# Full of this shit
# And I will ignore you, you
#
# I am not waiting for
# A prince on a white horse just to save me
# I know I have to do by myself
# And this time I will be free
#
# I am ignoring you
# I will ignore you
# I am ignoring you
# I will ignore you
# Cause your heart is so
# Full of this shit
# And I will ignore
# I will ignore
# I will ignore you
# Ignoring you
# Ignoring you

# %%
## Retornar as letras/artistas com Affin score maior do que zero
dados.loc[dados.afinn_score > 0,]
# Out:
#                      artist  \
# 2                    Criolo
# 4                    Criolo
# 14                   Criolo
# 20                   Criolo
# 21                   Criolo
# 28                   Criolo
# 30                   Criolo
# 31                   Criolo
# 57                   Criolo
# 59                   Criolo
# 63                   Criolo
# 64                   Criolo
# 68                   Criolo
# 88              Fernandinho
# 89              Fernandinho
# 92              Fernandinho
# 95              Fernandinho
# 96              Fernandinho
# 103             Fernandinho
# 104             Fernandinho
# 108             Fernandinho
# 109             Fernandinho
# 111             Fernandinho
# 114             Fernandinho
# 117             Fernandinho
# 118             Fernandinho
# 122             Fernandinho
# 124             Fernandinho
# 125             Fernandinho
# 126             Fernandinho
# 131             Fernandinho
# 143  Os Barões da Pisadinha
# 146  Os Barões da Pisadinha
# 163  Os Barões da Pisadinha
# 171  Os Barões da Pisadinha
# 174  Os Barões da Pisadinha
# 196  Os Barões da Pisadinha
# 251                   Pitty
# 252                   Pitty
# 257                   Pitty
# 262                   Pitty
# 267                   Pitty
# 273                   Pitty
# 276                   Pitty
# 277                   Pitty
# 278                   Pitty
# 285                   Pitty
# 328                   Pitty
# 329                   Pitty
# 345                   Pitty
# 349                   Pitty
# 359                   Pitty
#
#                                             full_title  \
# 2                             Ainda Há Tempo by Criolo
# 4                                   Aprendiz by Criolo
# 14        Cartão de Visita by Criolo (Ft. Tulipa Ruiz)
# 20              Cigano by Criolo (Ft. The Abyssinians)
# 21                              Cóccix-ência by Criolo
# 28                             Duas de Cinco by Criolo
# 30                         Espiral de Ilusão by Criolo
# 31                        Esquiva da Esgrima by Criolo
# 57                Plano de Voo by Criolo (Ft. Síntese)
# 59          Que Bloco É Esse? by Criolo (Ft. Ilê Aiyê)
# 63                              Samba Sambei by Criolo
# 64                    Samba Sambei (Dub Mix) by Criolo
# 68                                Tô Pra Ver by Criolo
# 88                          Eis-me Aqui by Fernandinho
# 89                      Eu fui comprado by Fernandinho
# 92                           Faz Chover by Fernandinho
# 95                              Galileu by Fernandinho
# 96          Galileu (Remix) by Fernandinho (Ft. DJ PV)
# 103                Jesus, filho de deus by Fernandinho
# 104                        Luz do Mundo by Fernandinho
# 108                 Nada Além do Sangue by Fernandinho
# 109                        Não Há Outro by Fernandinho
# 111                              O hino by Fernandinho
# 114                              Perdão by Fernandinho
# 117                             Sara-me by Fernandinho
# 118                 Semelhantes A Jesus by Fernandinho
# 122                    Temos Que Ser Um by Fernandinho
# 124     Todas As Coisas/Tudo Entregarei by Fernandinho
# 125                      Totalmente Teu by Fernandinho
# 126                      Tua Fidelidade by Fernandinho
# 131                     Vento Impetuoso by Fernandinho
# 143  Beijo do Vampiro by Os Barões da Pisadinha (Ft...
# 146    Chama as Vaqueirinhas by Os Barões da Pisadinha
# 163                Fiat Toro by Os Barões da Pisadinha
# 171  Já Que Me Ensinou a Beber by Os Barões da Pisa...
# 174             Liga Pro 190 by Os Barões da Pisadinha
# 196                 Recairei by Os Barões da Pisadinha
# 251                     Desconstruindo Amélia by Pitty
# 252           Desconstruindo Amélia - Ao Vivo by Pitty
# 257                         Digging The Grave by Pitty
# 262                        Equalize - Ao Vivo by Pitty
# 267                          Go With The Flow by Pitty
# 273                       Just Now (Só Agora) by Pitty
# 276                                   Máscara by Pitty
# 277                         Máscara - Ao Vivo by Pitty
# 278  Máscara / Bonecas Pretas  - Ao Vivo by Pitty (...
# 285                        Memórias - Ao Vivo by Pitty
# 328                            Semana Que Vem by Pitty
# 329                  Semana Que Vem - Ao Vivo by Pitty
# 345                                 Stay Away by Pitty
# 349  Te Conecta / Tudo Me Faz Sentido - Ao Vivo by ...
# 359                                   Um Leão by Pitty
#
#                                                 lyrics lyrics_state  \
# 2    [Verso 1]\nVocê quer saber, então vou te falar...     complete
# 4    [Refrão 2x]\nEu quero algo de bom pra você e p...     complete
# 14   [Verso 1: Criolo]\nAcende o incenso de mirra f...     complete
# 20   [Letra de "Cigano" com Criolo & The Abyssinian...     complete
# 21   [Intro]\nDeixa o sangue coalhar\nDeixa o orval...     complete
# 28   [Refrão]\nCompro uma pistola do vapor\nVisto o...     complete
# 30   [Refrão]\nComo você dorme com isso?\nComo você...     complete
# 31   [Verso 1]\nFalar demais chiclete azeda\nChama ...     complete
# 57   [Verso 1: Criolo]\nE por mais que eu tente exp...     complete
# 59   [Verso 1: Criolo]\nHoje terra vai tremer\nHoje...     complete
# 63   Samba assim, samba sambei\nMas não esqueci das...     complete
# 64   Samba assim, samba sambei\nMas não esqueci das...     complete
# 68   [Letra de "Tô Pra Ver" com Criolo]\n\n[Refrão]...     complete
# 88   Quero morrer pra mim mesmo\nQuero levar a minh...     complete
# 89   Eu fui comprado, justificado\nA minha vida foi...     complete
# 92   Assim como a corsa\nAnseia por águas\nComo ter...     complete
# 95   [Letra de "Galileu" com Fernandinho]\n\n[Verso...     complete
# 96   [Letra de "Galileu (Remix)" com Fernandinho ft...     complete
# 103  Deixou os céus para me encontrar\nAqui não é o...     complete
# 104  No princípio era o verbo\nE o verbo era Deus\n...     complete
# 108  Teu Sangue leva-me além\nA todas as alturas\nO...     complete
# 109  Não há outro lugar\nNão há outra pessoa\nQue e...     complete
# 111  Posso ouvir os passos do meu Rei\nPosso escuta...     complete
# 114  Somos um jardim diante do Senhor\nJardim regad...     complete
# 117  O mesmo Jesus que andou em Jerusalém\nO mesmo ...     complete
# 118  Há um só corpo, uma só família\nUm só Senhor e...     complete
# 122  Amai-vos uns aos outros\nSujeitai-vos uns aos ...     complete
# 124  Eu sei que sempre estás comigo Senhor\nTambem ...     complete
# 125  Eu quero ser\nComo vaso em\nTuas mãos\nEu quer...     complete
# 126  Tua fidelidade Senhor\nVai mais fundo que os m...     complete
# 131  Doce presença\nPerfume suave\nEu Sei que estás...     complete
# 143  [Intro: Rodrigo Barão]\nPra tocar em todos os ...     complete
# 146  O paredão já tá ligado e a cerveja geladinha\n...     complete
# 163  E aí Carol, tudo bem, bebê\nQue tal dar um rol...     complete
# 171  Eu prometi não mais te procurar\nMas hoje não ...     complete
# 174  Não sei mais o que fazer\nDeu vontade de beber...     complete
# 196  Já faz uma semana\nQue eu to limpo de você\nIê...     complete
# 251  [Letra de "Desconstruindo Amélia", de Pitty]\n...     complete
# 252  [Letra de "Desconstruindo Amélia - Ao Vivo", d...     complete
# 257  [Letra de "Digging The Grave" com Pitty]\n\n[V...     complete
# 262  [Letra de "Equalize - Ao Vivo", de Pitty]\n\nÀ...     complete
# 267  She said 'I'll throw myself away\nThey're just...     complete
# 273  My child, so much to learn\nFeel my breast fee...     complete
# 276  [Letra de "Máscara" com Pitty]\n\n[Verso 1]\nD...     complete
# 277  [Letra de "Máscara - Ao Vivo", de Pitty]\n\nHe...     complete
# 278  [Letra de "Máscara / Bonecas Pretas - Ao Vivo"...     complete
# 285  [Letra de "Memórias - Ao Vivo", de Pitty]\n\nE...     complete
# 328  [Letra de "Semana Que Vem", de Pitty]\n\n[Vers...     complete
# 329  [Letra de "Semana Que Vem - Ao Vivo", de Pitty...     complete
# 345  Monkey see, monkey do\nRather be dead than coo...     complete
# 349  [Letra de "Te Conecta / Tudo Me Faz Sentido - ...     complete
# 359  [Letra de "Um Leão", de Pitty]\n\n[Verso 1]\nE...     complete
#
#                                            letra_limpa  \
# 2    \nVocê quer saber, então vou te falar\nPorque ...
# 4    \nEu quero algo de bom pra você e pra mim\nE p...
# 14   \nAcende o incenso de mirra francesa\nAlgodão ...
# 20   \n\n\nJah-Van\nJah-Van\nJah-Van\nJah-Van\n\n\n...
# 21   \nDeixa o sangue coalhar\nDeixa o orvalho seca...
# 28   \nCompro uma pistola do vapor\nVisto o jaco Ca...
# 30   \nComo você dorme com isso?\nComo você dorme t...
# 31   \nFalar demais chiclete azeda\nChama o SAMU e ...
# 57   \nE por mais que eu tente explicar, não consig...
# 59   \nHoje terra vai tremer\nHoje terra vai tremer...
# 63   Samba assim, samba sambei\nMas não esqueci das...
# 64   Samba assim, samba sambei\nMas não esqueci das...
# 68   \n\n\nTô pra ver um daqui sucumbir\nVocê pode ...
# 88   Quero morrer pra mim mesmo\nQuero levar a minh...
# 89   Eu fui comprado, justificado\nA minha vida foi...
# 92   Assim como a corsa\nAnseia por águas\nComo ter...
# 95   \n\n\nDeixou Sua glória\nFoi por amor, foi por...
# 96   " com Fernandinho ft. DJ PV]\n\n\nDeixou Sua g...
# 103  Deixou os céus para me encontrar\nAqui não é o...
# 104  No princípio era o verbo\nE o verbo era Deus\n...
# 108  Teu Sangue leva-me além\nA todas as alturas\nO...
# 109  Não há outro lugar\nNão há outra pessoa\nQue e...
# 111  Posso ouvir os passos do meu Rei\nPosso escuta...
# 114  Somos um jardim diante do Senhor\nJardim regad...
# 117  O mesmo Jesus que andou em Jerusalém\nO mesmo ...
# 118  Há um só corpo, uma só família\nUm só Senhor e...
# 122  Amai-vos uns aos outros\nSujeitai-vos uns aos ...
# 124  Eu sei que sempre estás comigo Senhor\nTambem ...
# 125  Eu quero ser\nComo vaso em\nTuas mãos\nEu quer...
# 126  Tua fidelidade Senhor\nVai mais fundo que os m...
# 131  Doce presença\nPerfume suave\nEu Sei que estás...
# 143  \nPra tocar em todos os paredões do Brasil, be...
# 146  O paredão já tá ligado e a cerveja geladinha\n...
# 163  E aí Carol, tudo bem, bebê\nQue tal dar um rol...
# 171  Eu prometi não mais te procurar\nMas hoje não ...
# 174  Não sei mais o que fazer\nDeu vontade de beber...
# 196  Já faz uma semana\nQue eu to limpo de você\nIê...
# 251  \n\n\nJá é tarde, tudo está certo\nCada coisa ...
# 252  \n\n\nJá é tarde, tudo está certo\nCada coisa ...
# 257  \n\n\nIt would be wrong to ask you why\nBecaus...
# 262  \n\nÀs vezes se eu me distraio\nSe eu não me v...
# 267  She said 'I'll throw myself away\nThey're just...
# 273  My child, so much to learn\nFeel my breast fee...
# 276  \n\n\nDiga\nQuem você é, me diga\nMe fale sobr...
# 277  \n\nHere we go!\n\n\nDiga\n\nEu sou a Pitty, b...
# 278  \n\nVem!\n\nDiga\nQuem você é, me diga\nMe fal...
# 285  \n\nEu fui matando os meus heróis\nAos poucos ...
# 328  \n\n\nAmanhã eu vou revelar\nDepois eu penso e...
# 329  \n\nAmanhã eu vou revelar\nDepois eu penso em ...
# 345  Monkey see, monkey do\nRather be dead than coo...
# 349  \n\n\nEi\nQuero ver chegar junto, hein?\nEi\n\...
# 359  \n\n\nEi, meu bem, faz um favor\nTraz alguém q...
#
#                                     text_sem_stopwords  \
# 2    quer saber então vou falar porque pessoas sadi...
# 4    quero algo bom pra pra mim pra outra pessoa po...
# 14   acende incenso mirra francesa algodão fio  toa...
# 20   jah van jah van jah van jah van querer viver p...
# 21   deixa sangue coalhar deixa orvalho secar amanh...
# 28   compro pistola vapor visto jaco califórnia azu...
# 30   dorme dorme tranquilo magoou destruiu desandou...
# 31   falar demais chiclete azeda chama samu ensina ...
# 57   tente explicar consigo tornar concreto abstrat...
# 59   hoje terra vai tremer hoje terra vai tremer vu...
# 63   samba assim samba sambei esqueci palavras rei ...
# 64   samba assim samba sambei esqueci palavras rei ...
# 68   tô pra ver daqui sucumbir pode sorrir final va...
# 88   quero morrer pra mim quero levar cruz coisas v...
# 89   comprado justificado vida paga lá cruz passado...
# 92   assim corsa anseia águas terra seca precisa ch...
# 95   deixou glória amor amor sangue derramou grande...
# 96   fernandinho ft dj pv deixou glória amor amor s...
# 103  deixou céus encontrar aqui lugar amor assim mu...
# 104  princípio verbo verbo deus verbo deus tudo fei...
# 108  sangue leva além todas alturas onde ouço voz f...
# 109  outro lugar outra pessoa queira ver outro abra...
# 111  posso ouvir passos rei posso escutar coração e...
# 114  jardim diante senhor jardim regado graça amor ...
# 117  jesus andou jerusalém jesus andou judéia jesus...
# 118  corpo família senhor bom pastor almas fé batis...
# 122  amai uns outros sujeitai uns outros quiser ser...
# 124  sei sempre estás comigo senhor tambem sei nada...
# 125  quero ser vaso mãos quero ser jardim regado ti...
# 126  fidelidade senhor vai fundo mares fidelidade s...
# 131  doce presença perfume suave sei estás és bem v...
# 143  pra tocar todos paredões brasil bebê vem comig...
# 146  paredão tá ligado cerveja geladinha chama vaqu...
# 163  aí carol tudo bem bebê tal dar rolé fiat toro ...
# 171  prometi procurar hoje dia sorte achei foto cel...
# 174  sei fazer deu vontade beber to arrependendo fi...
# 196  faz semana to limpo iêiê iêiê olhar stories si...
# 251  tarde tudo certo cada coisa posta lugar filho ...
# 252  tarde tudo certo cada coisa posta lugar filho ...
# 257  it would be wrong to ask you why because i kno...
# 262  vezes distraio vigio instante transporto pra p...
# 267  she said i'll throw myself away they're just p...
# 273  my child so much to learn feel my breast feed ...
# 276  diga diga fale sobre estrada conte sobre vida ...
# 277  here we go diga pitty beleza fale sobre estrad...
# 278  vem diga diga fale sobre estrada conte sobre v...
# 285  matando heróis poucos nenhuma lição pra aprend...
# 328  amanhã vou revelar penso aprender daqui uns di...
# 329  amanhã vou revelar penso aprender daqui uns di...
# 345  monkey see monkey rather be dead than cool eve...
# 349  ei quero ver chegar junto hein ei pra pensar l...
# 359  ei bem faz favor traz alguém saiba amor porém ...
#
#                                         text_sem_token  \
# 2    [quer, saber, entao, vou, falar, porque, pesso...
# 4    [quero, algo, bom, pra, pra, mim, pra, outra, ...
# 14   [acende, incenso, mirra, francesa, algodao, fi...
# 20   [jah, van, jah, van, jah, van, jah, van, quere...
# 21   [deixa, sangue, coalhar, deixa, orvalho, secar...
# 28   [compro, pistola, vapor, visto, jaco, californ...
# 30   [dorme, dorme, tranquilo, magoou, destruiu, de...
# 31   [falar, demais, chiclete, azeda, chama, samu, ...
# 57   [tente, explicar, consigo, tornar, concreto, a...
# 59   [hoje, terra, vai, tremer, hoje, terra, vai, t...
# 63   [samba, assim, samba, sambei, esqueci, palavra...
# 64   [samba, assim, samba, sambei, esqueci, palavra...
# 68   [to, pra, ver, daqui, sucumbir, pode, sorrir, ...
# 88   [quero, morrer, pra, mim, quero, levar, cruz, ...
# 89   [comprado, justificado, vida, paga, la, cruz, ...
# 92   [assim, corsa, anseia, aguas, terra, seca, pre...
# 95   [deixou, gloria, amor, amor, sangue, derramou,...
# 96   [fernandinho, ft, dj, pv, deixou, gloria, amor...
# 103  [deixou, ceus, encontrar, aqui, lugar, amor, a...
# 104  [principio, verbo, verbo, deus, verbo, deus, t...
# 108  [sangue, leva, alem, todas, alturas, onde, ouc...
# 109  [outro, lugar, outra, pessoa, queira, ver, out...
# 111  [posso, ouvir, passos, rei, posso, escutar, co...
# 114  [jardim, diante, senhor, jardim, regado, graca...
# 117  [jesus, andou, jerusalem, jesus, andou, judeia...
# 118  [corpo, familia, senhor, bom, pastor, almas, f...
# 122  [amai, uns, outros, sujeitai, uns, outros, qui...
# 124  [sei, sempre, estas, comigo, senhor, tambem, s...
# 125  [quero, ser, vaso, maos, quero, ser, jardim, r...
# 126  [fidelidade, senhor, vai, fundo, mares, fideli...
# 131  [doce, presenca, perfume, suave, sei, estas, e...
# 143  [pra, tocar, todos, paredoes, brasil, bebe, ve...
# 146  [paredao, ta, ligado, cerveja, geladinha, cham...
# 163  [ai, carol, tudo, bem, bebe, tal, dar, role, f...
# 171  [prometi, procurar, hoje, dia, sorte, achei, f...
# 174  [sei, fazer, deu, vontade, beber, to, arrepend...
# 196  [faz, semana, to, limpo, ieie, ieie, olhar, st...
# 251  [tarde, tudo, certo, cada, coisa, posta, lugar...
# 252  [tarde, tudo, certo, cada, coisa, posta, lugar...
# 257  [it, would, be, wrong, to, ask, you, why, beca...
# 262  [vezes, distraio, vigio, instante, transporto,...
# 267  [she, said, i'll, throw, myself, away, they're...
# 273  [my, child, so, much, to, learn, feel, my, bre...
# 276  [diga, diga, fale, sobre, estrada, conte, sobr...
# 277  [here, we, go, diga, pitty, beleza, fale, sobr...
# 278  [vem, diga, diga, fale, sobre, estrada, conte,...
# 285  [matando, herois, poucos, nenhuma, licao, pra,...
# 328  [amanha, vou, revelar, penso, aprender, daqui,...
# 329  [amanha, vou, revelar, penso, aprender, daqui,...
# 345  [monkey, see, monkey, rather, be, dead, than, ...
# 349  [ei, quero, ver, chegar, junto, hein, ei, pra,...
# 359  [ei, bem, faz, favor, traz, alguem, saiba, amo...
#
#                                   TextBlob_score  afinn_score
# 2                                     (0.0, 0.0)          1.0
# 4                                     (0.2, 0.2)          1.0
# 14                                   (-0.8, 1.0)          2.0
# 20                                    (0.0, 0.0)          3.0
# 21                                    (0.0, 0.0)          6.0
# 28                                   (0.0, 0.25)         36.0
# 30                                   (0.0, 0.75)          2.0
# 31    (-0.20833333333333331, 0.5916666666666667)          1.0
# 57                                    (0.1, 0.4)          2.0
# 59   (0.016666666666666677, 0.31666666666666665)          2.0
# 63    (-0.23333333333333334, 0.5166666666666666)          1.0
# 64    (-0.23333333333333334, 0.5166666666666666)          1.0
# 68                             (0.0125, 0.90625)          4.0
# 88                                    (0.0, 0.0)          1.0
# 89                                    (0.0, 0.0)          4.0
# 92                                    (0.0, 0.0)          2.0
# 95                                    (0.0, 0.0)         28.0
# 96                                    (0.0, 0.0)         21.0
# 103                                   (0.0, 0.0)          6.0
# 104                                   (0.0, 0.0)          4.0
# 108                                   (0.0, 0.0)          4.0
# 109                                   (0.0, 0.0)          4.0
# 111                                   (0.0, 0.0)          1.0
# 114                                   (0.0, 0.0)          1.0
# 117                                   (0.0, 0.0)          6.0
# 118                                   (0.0, 0.0)          5.0
# 122                                   (0.0, 0.0)          1.0
# 124                                   (0.0, 0.0)          3.0
# 125                                   (0.0, 0.0)          7.0
# 126                                   (0.0, 0.0)          2.0
# 131                                   (0.0, 0.0)          4.0
# 143                                   (0.5, 0.6)         24.0
# 146                                   (0.5, 0.5)          6.0
# 163                                   (0.5, 0.6)          6.0
# 171                                   (0.0, 0.0)          4.0
# 174                                   (0.0, 1.0)          2.0
# 196                                   (0.5, 0.6)          6.0
# 251                                   (0.0, 0.0)          4.0
# 252                                   (0.0, 0.0)          4.0
# 257    (0.0967948717948718, 0.48333333333333345)         11.0
# 262                                   (0.0, 0.0)          1.0
# 267    (0.34852272727272726, 0.5354545454545454)         12.0
# 273     (0.4833333333333334, 0.5333333333333333)         13.0
# 276                                   (0.0, 0.5)          8.0
# 277                  (-0.12, 0.5599999999999999)          4.0
# 278                                   (0.0, 0.5)          8.0
# 285                                 (-0.05, 0.4)          1.0
# 328                                   (0.0, 0.0)          2.0
# 329                                   (0.0, 0.0)          2.0
# 345     (0.0824074074074074, 0.3583333333333333)          1.0
# 349                                   (0.0, 0.0)          4.0
# 359                                   (0.0, 0.0)          2.0

# %%
## Maior score

print(dados['lyrics'][28])
# Out:
# [Refrão]
# Compro uma pistola do vapor
# Visto o jaco Califórnia azul
# Faço uma mandinga pro terror
# E vou...
#
# [Verso 1]
# É o cão, é o cânhamo, é o desamor
# É o canhão na boca de quem tanto se humilhou
# Inveja é um desgraça, alastra ódio e rancor
# E cocaína é uma igreja gringa de le chereau
# Pra cada rap escrito é uma alma que se salva
# O rosto do carvoeiro é o Brasil que mostra a cara
# Muito blá se fala, e a língua é uma piranha
# Aqui é só trabalho, sorte é pras crianças
# Que vê o professor em desespero na miséria
# Que no meio do caminho da educação havia uma pedra
# E havia uma pedra no meio do caminho
# Ele não é preto véi mas no bolso leva um cachimbo
# É o sleazestack, dos zóio branco, repara o brilho
# Chewbacca na penha é maizena com pó de vidro
# Comerciais de TV, glamour pra alcoolismo
# É o Kinect do XBox por duas buchas de cinco
# HA-HA-HA-HA-HA-HA
# HA-HA-HA-HA-HA-HA
# Chega a rir de nervoso, comédia vai chorar
#
# [Refrão]
# Compro uma pistola do vapor
# Visto o jaco Califórnia azul
# Faço uma mandinga pro terror
# E vou...
#
# [Verso 2]
# E eu fico aqui pregando a paz
# E a cada maço de cigarro fumado a morte faz um jaz
# Entre nós, cá pra nós, e se um de nós morrer
# Pra vocês é uma beleza
# Desigualdade faz tristeza
# Na montanha dos sete abutres alguém enfeita sua mesa
# Um governo que quer acabar com o crack
# Mas não tem moral para vetar comercial de cerveja
# Alô, Foucault, cê quer saber o que é loucura?
# É ver Hobsbawm na mão dos boy, Maquiavel nessa leitura
# Falar pra um favelado que a vida não é dura
# E achar que teu doze de condomínio não carrega a mesma culpa
# É salto alto, MD, Absolut, suco de fruta
# Mas nem todo mundo é feliz nessa fé absoluta
# Calma, filha, que esse doce não é sal de fruta
# Azedar é a meta, tá bom ou quer mais açúcar?
# HA-HA-HA-HA-HA-HA
# HA-HA-HA-HA-HA-HA
# Chega a rir de nervoso, comédia vai chorar
#
# [Refrão]
# Compro uma pistola do vapor
# Visto o jaco Califórnia azul
# Faço uma mandinga pro terror
# E vou...
# Compro uma pistola do vapor
# Visto o jaco Califórnia azul
# Faço uma mandinga pro terror
# E vou...

# %% [markdown]
# ## 4 Tópicos - Análises Por Artistas
# Realização de outras análises selecionando apenas o artista

# %% [markdown]
# ## 4.1 Criolo - Rapper

# %%
criolo=dados.loc[dados['artist']=='Criolo']

# %%
## Ocorrencia palavras mais ditas
words = criolo['text_sem_token'].dropna()\
                            #.apply(lambda y: pd.value_counts(re.findall('([\s]\w+[\s])',' '.join(y))))\
                            .sum(axis=0)\
                            .to_frame()\
                            .reset_index()\
                            .sort_values(by=0,ascending=False)
words.columns = ['word','occurences']

# %%
words.head()
# Out:
#       word  occurences
# 0     pra        184.0
# 63    vai         69.0
# 127   vou         50.0
# 274    pa         46.0
# 186    ta         42.0

# %%
bigramseries = pd.Series([word for sublist in criolo['text_sem_token'].dropna()\
                    .apply(lambda x: [i for i in bigrams(x)])\
                    .tolist() for word in sublist])\
                    .value_counts()

# %%
bigramseries.head(20)
# Out:
# (pa, pa)             78
# (homo, homo)         36
# (oh, laraie)         32
# (luta, luta)         32
# (laraie, oh)         28
# (ninguem, vai)       28
# (pra, ver)           27
# (ha, ha)             24
# (e, mario)           24
# (adjo, e)            24
# (ogum, adjo)         24
# (pra, mim)           22
# (mario, ogum)        22
# (to, pra)            19
# (ver, daqui)         19
# (aguas, mar)         18
# (daqui, sucumbir)    17
# (ai, ai)             16
# (quero, ver)         13
# (vai, chorar)        13
# dtype: int64

# %% [markdown]
# ## 4.2 Fernandinho - Artista Gospel

# %%
fernandinho=dados.loc[dados['artist']=='Fernandinho']
## Ocorrencia palavras mais ditas
words = fernandinho['text_sem_token'].dropna()\
                            #.apply(lambda y: pd.value_counts(re.findall('([\s]\w+[\s])',' '.join(y))))\
                            .sum(axis=0)\
                            .to_frame()\
                            .reset_index()\
                            .sort_values(by=0,ascending=False)
words.columns = ['word','occurences']
words.head()
# Out:
#         word  occurences
# 32     deus         66.0
# 93      mim         62.0
# 92    santo         52.0
# 195   jesus         45.0
# 43       ti         39.0

# %%
bigramseries = pd.Series([word for sublist in fernandinho['text_sem_token'].dropna()\
                    .apply(lambda x: [i for i in bigrams(x)])\
                    .tolist() for word in sublist])\
                    .value_counts()
bigramseries.head(20)
# Out:
# (santo, santo)       60
# (pra, mim)           56
# (oh, oh)             35
# (deus, melhor)       28
# (melhor, pra)        28
# (jesus, jesus)       25
# (chuva, chuva)       24
# (cantam, santo)      22
# (galileu, jesus)     22
# (nova, historia)     20
# (deus, pra)          20
# (leva, leva)         18
# (todos, cantam)      18
# (jesus, galileu)     17
# (compara, vir)       16
# (nunca, atingido)    16
# (santo, todos)       15
# (mim, perdido)       14
# (rei, reis)          14
# (mim, deus)          14
# dtype: int64

# %% [markdown]
# ## 4.3 Os Barões da Pisadinha - Forró

# %%
baroes=dados.loc[dados['artist']=='Os Barões da Pisadinha']
## Ocorrencia palavras mais ditas
words = baroes['text_sem_token'].dropna()\
                            #.apply(lambda y: pd.value_counts(re.findall('([\s]\w+[\s])',' '.join(y))))\
                            .sum(axis=0)\
                            .to_frame()\
                            .reset_index()\
                            .sort_values(by=0,ascending=False)
words.columns = ['word','occurences']
words.head()
# Out:
#       word  occurences
# 3     pra        124.0
# 31   amor         80.0
# 20     ta         64.0
# 32    vou         56.0
# 18    vai         52.0

# %%
bigramseries = pd.Series([word for sublist in baroes['text_sem_token'].dropna()\
                    .apply(lambda x: [i for i in bigrams(x)])\
                    .tolist() for word in sublist])\
                    .value_counts()
bigramseries.head(20)
# Out:
# (oh, oh)                48
# (e, e)                  20
# (din, din)              16
# (fazer, amor)           15
# (vai, ter)              14
# (espinhaco, veio)       14
# (ah, ah)                14
# (pra, mim)              13
# (voltar, pra)           13
# (amor, despedida)       13
# (to, zero)              12
# (bebo, amor)            12
# (esquema, preferido)    12
# (senta, aqui)           12
# (ei, ei)                12
# (veio, quebrou)         12
# (bebe, ta)              12
# (gente, faz)            12
# (aqui, senta)           12
# (vai, doer)             12
# dtype: int64

# %% [markdown]
# ## 4.4 Pitty - Rock

# %%
pitty=dados.loc[dados['artist']=='Pitty']
## Ocorrencia palavras mais ditas
words = baroes['text_sem_token'].dropna()\
                           #.apply(lambda y: pd.value_counts(re.findall('([\s]\w+[\s])',' '.join(y))))\
                            .sum(axis=0)\
                            .to_frame()\
                            .reset_index()\
                            .sort_values(by=0,ascending=False)
words.columns = ['word','occurences']
words.head()
# Out:
#       word  occurences
# 3     pra        124.0
# 31   amor         80.0
# 20     ta         64.0
# 32    vou         56.0
# 18    vai         52.0

# %%
bigramseries = pd.Series([word for sublist in pitty['text_sem_token'].dropna()\
                    .apply(lambda x: [i for i in bigrams(x)])\
                    .tolist() for word in sublist])\
                    .value_counts()
bigramseries.head(20)
# Out:
# (roda, gira)          44
# (gira, gira)          39
# (gira, roda)          39
# (roda, roda)          34
# (ah, ah)              33
# (homem, lobo)         32
# (bizarro, bizarro)    30
# (semana, vem)         28
# (oh, oh)              27
# (namah, shivaya)      26
# (om, namah)           26
# (lobo, homem)         26
# (queimar, novo)       25
# (tarde, demais)       25
# (nunca, tarde)        25
# (faz, queimar)        25
# (gente, junta)        24
# (junta, pra)          24
# (onde, ir)            24
# (i, will)             24
# dtype: int64

# %% [markdown]
# ## 5 Conclusão

# %% [markdown]
# As letras de música são uma excelente forma de estudar representação textual.O conteúdo é bastante rico, tanto pela poética - vide Criolo - ou expressões populares, como as canções de Os Barões da Pisadinha. <br>
#
# Como ponto positivo, destaca-se o metodo de encontrar similaridade entre as palavras!!
#
# Um ponto de dificuldade encontrado está nas representações como "ah", "ha", que normalmente fazem parte da fonética da canção. Além disso, outra dificuldade encontrada está na análise de sentimentos. Os métodos aqui estudados, na grande maioria das canções, obteve-se um score neutro.<br>
#
# Para futuros trabalhos, sugere-se a utilização de canções por décadas. Pode-se levantar como hipótese se há diferença entre as palavras das músicas dos anos 80 para as palavras das canções dos anos 2010. Será que existe diferença?
